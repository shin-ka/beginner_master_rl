# %% [markdown]
# <div style="text-align:center">
#     <h1>
#         Policy Iteration
#     </h1>
# </div>
# <br>
#
# <div style="text-align:center">
#     <p>
#         In this notebook we are going to look at a dynamic programming algorithm called policy iteration. In it, we will iteratively interleave two processes: policy evaluation and policy improvement, until the optimal policy and state values are found.
#     </p>
# </div>
#
# <br><br>
# <div style="text-align:center">
#     <b>This notebook belongs to section 3 of the course "Reinforcement Learning: beginner to master".</b>
#     <br><br>
#     <a href="https://www.udemy.com">Reinforcement Learning: beginner to master</a> (English)
#     <br>
#     <a href="https://www.udemy.com">Reinforcement Learning: de principiante a maestro</a> (Spanish)
# </div>
#
# <br>
#
# <table style="width:35%">
#   <tr style="background-color: transparent">
#     <td style="width: 45%">
#         <a target="_parent" href="https://www.evlabs.io" style="float: center">
#             <img src="img/evlabs-square.png" width="75"/>
#         </a>
#     </td>
#     <td valign="bottom">
#         <a target="_parent" href="https://www.youtube.com/channel/UCksRNSzWuMV5IfdrPlglqqw">
#             <img src="img/YouTube.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://www.linkedin.com/company/evlabs">
#             <img src="img/LinkedIn.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://twitter.com/evelabs">
#             <img src="img/Twitter.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://github.com/escape-velocity-labs/">
#             <img src="img/GitHub.png" width="35"/>
#         </a>
#     </td>
#
#   </tr>
#   <tr style="background-color: transparent">
#     <th style="text-align: center; width: 70%">Escape Velocity Labs</th>
#   </tr>
#
# </table>
#
# <br>

# %% [markdown]
# ## Import the necessary software libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt

from envs import Maze
from utils import plot_policy, plot_values, test_agent

# %% [markdown]
# ## Initialize the environment

# %%
env = Maze()

# %%
frame = env.render(mode='rgb_array')
plt.axis('off')
plt.imshow(frame)

# %%
print(f"Observation space shape: {env.observation_space.nvec}")
print(f"Number of actions: {env.action_space.n}")
# Out:
# Observation space shape: [5 5]
# Number of actions: 4

# %% [markdown]
# ## Define the policy $\pi(\cdot|s)$

# %% [markdown]
# #### Create the policy $\pi(\cdot|s)$

# %%
policy_probs = np.full((5, 5, 4), 0.25)

# %%
def policy(state):
    return policy_probs[state]

# %% [markdown]
# #### Test the policy with state (0, 0)

# %%
action_probabilities = policy((0,0))
for action, prob in zip(range(4), action_probabilities):
    print(f"Probability of taking action {action}: {prob}")
# Out:
# Probability of taking action 0: 0.25
# Probability of taking action 1: 0.25
# Probability of taking action 2: 0.25
# Probability of taking action 3: 0.25

# %% [markdown]
# #### See how the random policy does in the maze

# %%
test_agent(env, policy, episodes=1)

# %% [markdown]
# #### Plot the policy

# %%
plot_policy(policy_probs, frame)

# %% [markdown]
# ## Define value table $V(s)$

# %% [markdown]
# #### Create the $V(s)$ table

# %%
state_values = np.zeros(shape=(5,5))

# %% [markdown]
# #### Plot $V(s)$

# %%
plot_values(state_values, frame)

# %% [markdown]
# ## Implement the Policy Iteration algorithm
#
# </br>
#
# ![Screenshot%202021-02-13%20at%2020.38.25.png](attachment:Screenshot%202021-02-13%20at%2020.38.25.png)
#
# <div style="text-align:center">
#     Adapted from Barto & Sutton: "Reinforcement Learning: An Introduction".
# </div>

# %% [markdown]
# Transitions between states are deterministic ($p(s', r| s, a) = 1$)

# %%
def policy_evaluation(policy_probs, state_values, theta=1e-6, gamma=0.99):
    delta = float("inf")
    
    while delta > theta:
        delta = 0
        for row in range(5): 
            for col in range(5): 
                old_value = state_values[(row,col)]
                new_value = 0.0
                action_probabilities = policy_probs[(row,col)] # because in line 10 of the algo, it is π(a|s)
                
                for action, prob in enumerate(action_probabilities):
                    next_state, reward, _, _ = env.simulate_step((row,col), action)
                    new_value += prob * (reward + gamma * state_values[next_state])
                
                state_values[(row,col)] = new_value
                
                delta = max(delta, abs(old_value - new_value))

# %%
def  policy_improvement(policy_probs, state_values, gamma=0.99):
    policy_stable = True
    
    for row in range(5): 
            for col in range(5):  
                # because in line 20, we compare old_action with π(s) and π(s) computed in line 19 is arg max
                # π(s) in line 19 is new action because π(s) --> a (definition of policy)
                old_action = policy_probs[(row,col)].argmax() 
                new_action = None
                max_qsa = float('-inf')
                for action in range(4):
                    next_state, reward, _, _ = env.simulate_step((row,col), action)
                    qsa = reward + gamma * state_values[next_state]
                    
                    if qsa > max_qsa:
                        max_qsa = qsa
                        new_action = action # we found an action with a greater value
                        
                action_probabilities = np.zeros(4)
                action_probabilities[new_action] = 1.0
                policy_probs[(row,col)] = action_probabilities # maximize the prob of the action which yields highest q(s,a)
                
                if old_action != new_action:
                    policy_stable = False
                    
    return policy_stable

# %%
def policy_iteration(policy_probs,state_values, theta=1e-6, gamma=0.99):
    policy_stable = False
    
    while not policy_stable:
        print("Policy Evaluation")
        policy_evaluation(policy_probs, state_values, theta, gamma)
        plot_values(state_values, frame)
        
        print("Policy Improvement")
        policy_stable = policy_improvement(policy_probs, state_values, gamma)
        plot_policy(policy_probs, frame)

# %%
policy_iteration(policy_probs, state_values)
# Out:
# Policy Evaluation
# Policy Improvement
# Policy Evaluation
# Policy Improvement

# %% [markdown]
# ## Show results

# %% [markdown]
# #### Test the resulting agent

# %%
test_agent(env, policy)

# %% [markdown]
# ## Resources

# %% [markdown]
# [[1] Reinforcement Learning: An Introduction. Ch. 4: Dynamic Programming](https://web.stanford.edu/class/psych209/Readings/SuttonBartoIPRLBook2ndEd.pdf)
